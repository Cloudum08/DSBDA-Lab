# %% [markdown]
# <a href="https://colab.research.google.com/github/Cloudum08/DSBDA-Lab/blob/main/DSBDAL_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Data Visualization I** (without preprocessing of data)

# %% [markdown]
# 1. Use the inbuilt dataset 'titanic'. The dataset contains 891 rows and contains information about the passengers who boarded the unfortunate Titanic ship. Use the Seaborn library to see if we can find any patterns in the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading the Dataset

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.notnull()
# Out:
#      survived  pclass   sex    age  sibsp  parch  fare  embarked  class   who  \
# 0        True    True  True   True   True   True  True      True   True  True
# 1        True    True  True   True   True   True  True      True   True  True
# 2        True    True  True   True   True   True  True      True   True  True
# 3        True    True  True   True   True   True  True      True   True  True
# 4        True    True  True   True   True   True  True      True   True  True
# ..        ...     ...   ...    ...    ...    ...   ...       ...    ...   ...
# 886      True    True  True   True   True   True  True      True   True  True
# 887      True    True  True   True   True   True  True      True   True  True
# 888      True    True  True  False   True   True  True      True   True  True
# 889      True    True  True   True   True   True  True      True   True  True
# 890      True    True  True   True   True   True  True      True   True  True
#
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# **Finding patterns of data**

# %% [markdown]
# **1. Distribution plots** :These plots help us to visualise the distribution of data. We can use these plots to understand the mean, median, range, variance, deviation, etc of the data.

# %% [markdown]
# a. Distplot : gives us the histogram of the selected continuous variable.

# %%
sns.distplot (df['age'], bins = 10)
# Out:
# <ipython-input-5-510c75b6815a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot (df['age'], bins = 10)
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot (x = df['age'], bins = 10, kde = False)
# Out:
# <ipython-input-7-70918041e863>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot (x = df['age'], bins = 10, kde = False)
# <Axes: >

# %% [markdown]
# Here the x-axis is the age and the y-axis displays frequency. For example, for bins = 10, there are around 50 people having age 0 to 10

# %% [markdown]
# b. Joint plot: It is the combination of the distplot of two variables. It is an example of bivariate analysis.

# %%
sns.jointplot (x = df['age'], y = df['fare'])

# %%
sns.jointplot (x = df['age'], y = df['fare'], kind = 'scatter')

# %% [markdown]
# there is no correlation observed between prices and the fares.

# %%
sns.jointplot (x = df['age'], y = df['fare'], kind = 'hex')

# %% [markdown]
# So if you look at the above plot, you can see that most of the passengers are between the ages of 20 and 30 and most of them paid between 10-50 for the tickets.

# %% [markdown]
# c. Rug plot: The rugplot() is used to draw small bars along the x-axis for each point in the dataset.

# %%
sns.rugplot(df['fare'])
# Out:
# <Axes: xlabel='fare'>

# %% [markdown]
# From the output, you can see that most of the instances for the fares have values between 0 and 100.

# %% [markdown]
# **2. Categorical plots**: used to plot categorical data. The categorical plots plot the values in the categorical column against another categorical column or
# a numeric column.

# %% [markdown]
# i. Bar Plots: The barplot() is used to display the mean value for each value in a categorical column, against a numeric column.

# %%
sns.barplot (x = 'sex', y = 'age', data = df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# the average age of male passengers is just less than 40 while the average age of female passengers is around 33.

# %%
sns.barplot (x = 'sex', y = 'age', data = df, estimator = np.std)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# ii. Count Plot: The count plot is similar to the bar plot, however it displays the count of the categories in a specific column.

# %%
sns.countplot(x = 'sex', data = df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# iii. Box Plot: The box plot is used to display the distribution of the categorical data in the form of quartiles. The centre of the box shows the median value.

# %%
sns.boxplot (x = 'sex', y = 'age', data = df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot (x = 'sex', y = 'age', data = df, hue = 'survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# iv. Violin Plot: allows us to display all the components that actually correspond to the data point.

# %%
sns.violinplot (x = 'sex', y = 'age', data = df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# from the violin plot for males, it is clearly evident that the number of passengers with age between 20 and 40 is higher than all the rest of the age brackets.

# %%
sns.violinplot (x = 'sex', y = 'age', data = df, hue = 'survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# **3. Advanced plots**

# %% [markdown]
# i. Strip Plot: draws a scatter plot where one of the variables is categorical.

# %%
sns.stripplot(x = 'sex', y = 'age', data = df, jitter = False)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x = 'sex', y = 'age', data = df, jitter = True)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x = 'sex', y = 'age', data = df, jitter = True, hue = 'survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# ii. Swarm Plot: is a combination of the strip and the violin plots. In the swarm plots, the points are adjusted in such a way that they don't overlap.

# %%
sns.swarmplot (x = 'sex', y = 'age', data = df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.swarmplot (x = 'sex', y = 'age', data = df, hue = 'survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# that the ratio of surviving males is less than the ratio of surviving
# females. Since for the male plot, there are more blue points and less orange points. On the other hand, for females, there are more orange points (surviving) than the blue points (not surviving). Another observation is that amongst males of age less than 10, more passengers survived as compared to those who didn't

# %% [markdown]
# **4. Matrix plots**: are the type of plots that show data in the form of rows and columns. Heat maps are the prime examples of matrix plots.

# %% [markdown]
# i. Heat Maps: used to plot correlation between numeric columns in the form of a
# matrix.

# %%
df.corr()
# Out:
# <ipython-input-24-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# ...

# %%
corr = df.corr()
sns.heatmap(corr)
# Out:
# <ipython-input-25-753ca5bff919>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <Axes: >

# %%
sns.heatmap(corr, annot = True)
# Out:
# <Axes: >

# %%
sns.heatmap(corr, cmap = 'Blues', annot = True)
# Out:
# <Axes: >

# %% [markdown]
# #**Data Visualization I** (with preprocessing of data)

# %% [markdown]
# I. Loading the Dataset, checking for null values and preprocessing data

# %%
df1 = sns.load_dataset('titanic')
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df1.shape
# Out:
# (891, 15)

# %%
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df1.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df1.describe(include = 'object')
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
df1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# II. Filling up the NULL values in the dataset.

# %%
df1['age'] = df1['age'].fillna(np.mean(df1['age']))

# %%
df1['deck'] = df1['deck'].fillna(df1['deck'].mode()[0])

# %%
df1['embark_town'] = df1['embark_town'].fillna(df1['embark_town'].mode()[0])

# %%
df1['embarked'] = df1['embarked'].fillna(df1['embarked'].mode()[0])

# %%
df1.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df1.head(n = 10)
# Out:
#    survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0         0       3    male  22.000000      1      0   7.2500        S
# 1         1       1  female  38.000000      1      0  71.2833        C
# 2         1       3  female  26.000000      0      0   7.9250        S
# 3         1       1  female  35.000000      1      0  53.1000        S
# 4         0       3    male  35.000000      0      0   8.0500        S
# 5         0       3    male  29.699118      0      0   8.4583        Q
# 6         0       1    male  54.000000      0      0  51.8625        S
# 7         0       3    male   2.000000      3      1  21.0750        S
# 8         1       3  female  27.000000      0      2  11.1333        S
# 9         1       2  female  14.000000      1      0  30.0708        C
#
#     class    who  adult_male deck  embark_town alive  alone
# 0   Third    man        True    C  Southampton    no  False
# 1   First  woman       False    C    Cherbourg   yes  False
# ...

# %% [markdown]
# III. Finding patterns of data

# %% [markdown]
# **1. Distribution plots**

# %% [markdown]
# a. Dist plot

# %%
sns.distplot(x = df1['age'], bins = 10)
# Out:
# <ipython-input-40-2bc27e173dad>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = df1['age'], bins = 10)
# <Axes: ylabel='Density'>

# %%
sns.distplot(x = df1['age'], bins = 10, kde = False)
# Out:
# <ipython-input-41-88bc91aaa657>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = df1['age'], bins = 10, kde = False)
# <Axes: >

# %% [markdown]
# b. Joint plot

# %%
sns.jointplot(x = df1['age'], y = df1['fare'], kind = 'scatter')

# %%
sns.jointplot(x = df1['age'], y = df1['fare'], kind = 'hex')

# %% [markdown]
# c. Rug plot

# %%
sns.rugplot(df1['fare'])
# Out:
# <Axes: xlabel='fare'>

# %% [markdown]
# **2. Categorical Plots**

# %% [markdown]
# a. Bar plot

# %%
sns.barplot (x = 'sex', y = 'age', data = df1)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot (x = 'sex', y = 'age', data = df1, estimator = np.std)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# b. Count plot

# %%
sns.countplot(x = 'sex', data = df1)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# c. Box plot

# %%
sns.boxplot (x = 'sex', y = 'age', data = df1)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot (x = 'sex', y = 'age', data = df1, hue = 'survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# d. Violin plot

# %%
sns.violinplot (x = 'sex', y = 'age', data = df1)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot (x = 'sex', y = 'age', data = df1, hue = 'survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# **3. Advanced Plots**

# %% [markdown]
# a. Strip plot

# %%
sns.stripplot (x = 'sex', y = 'age', data = df1, jitter = False)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot (x = 'sex', y = 'age', data = df1, jitter = True)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot (x = 'sex', y = 'age', data = df1, jitter = True, hue = 'survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# b. Swarm plot

# %%
sns.swarmplot (x = 'sex', y = 'age', data = df1, size = 1)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.swarmplot (x = 'sex', y = 'age', data = df1, size = 1, hue = 'survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# **4. Matrix plots**

# %% [markdown]
# a. Heat maps

# %%
df1.corr()
# Out:
# <ipython-input-57-49b3fcfeb4d1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.069809 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.331339  0.083081  0.018443 -0.549500
# age        -0.069809 -0.331339  1.000000 -0.232625 -0.179191  0.091566
# sibsp      -0.035322  0.083081 -0.232625  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.179191  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.091566  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.253236 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.179775 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# ...

# %%
corr = df1.corr()
sns.heatmap(corr)
# Out:
# <ipython-input-58-7884c29f6e71>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df1.corr()
# <Axes: >

# %%
sns.heatmap(corr, annot = True, cmap = 'Greens')
# Out:
# <Axes: >

# %%
sns.catplot(x= 'pclass', y = 'fare', data=df, kind = 'strip')

# %%
sns.catplot(x= 'sex', y = 'age', data=df1, kind = 'strip')

# %%
sns.pairplot(df1)

# %%
sns.scatterplot(x = 'fare', y = 'pclass', hue = 'survived', data = df1)
# Out:
# <Axes: xlabel='fare', ylabel='pclass'>

# %% [markdown]
# 2. Write a code to check how the price of the ticket (column name: 'fare') for each passenger is distributed by plotting a histogram.

# %%
sns.histplot(df['fare'], kde=False, bins=10)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(df['fare'], kde= True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(df['fare'], kde= True, bins = 15)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %% [markdown]
# Conclusion-
# Seaborn is an advanced data visualisation library built on top of Matplotlib library. In this assignment, we looked at how we can draw distributional and categorical plots using the Seaborn library. We have seen how to plot matrix plots in Seaborn. We also saw how to change plot styles and use grid functions to manipulate subplots.

# %%
# !jupyter nbconvert --to html /content/DSBDAL-8.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/DSBDAL-8.ipynb to html
# [NbConvertApp] Writing 2589065 bytes to /content/DSBDAL-8.html

# %%
# !apt-get install texlive texlive-xetex texlive-latex-extra pandoc
# !pip install pypandoc
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# pandoc is already the newest version (2.9.2.1-3ubuntu2).
# pandoc set to manually installed.
# The following additional packages will be installed:
#   dvisvgm fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono fonts-texgyre
#   fonts-urw-base35 libapache-pom-java libcommons-logging-java libcommons-parent-java
#   libfontbox-java libfontenc1 libgs9 libgs9-common libidn12 libijs-0.35 libjbig2dec0 libkpathsea6
#   libpdfbox-java libptexenc1 libruby3.0 libsynctex2 libteckit0 libtexlua53 libtexluajit2 libwoff1
#   libzzip-0-13 lmodern poppler-data preview-latex-style rake ruby ruby-net-telnet ruby-rubygems
#   ruby-webrick ruby-xmlrpc ruby3.0 rubygems-integration t1utils teckit tex-common tex-gyre
#   texlive-base texlive-binaries texlive-fonts-recommended texlive-latex-base
#   texlive-latex-recommended texlive-pictures texlive-plain-generic tipa xfonts-encodings
# ...

# %%
# !jupyter nbconvert --to PDF "DSBDAL-8.ipynb"
# Out:
# [NbConvertApp] Converting notebook DSBDAL-8.ipynb to PDF
# [NbConvertApp] Support files will be in DSBDAL-8_files/
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# [NbConvertApp] Making directory ./DSBDAL-8_files
# ...
